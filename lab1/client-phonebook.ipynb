# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance
# Out:
# 2024-11-01 16:49:28,962 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=57, family=2, type=1, proto=0, laddr=('127.0.0.1', 48500), raddr=('127.0.0.1', 50007)>

# %%
client.get_phonebook()
# Out:
# Phonebook:
# Alice: 1234
# Bob: 5678
# Charlie: 9012
# David: 3456
# Eve: 7890
# Frank: 1357
# Grace: 2468
# Heidi: 9753
# Ivan: 8642
# 'Alice: 1234\nBob: 5678\nCharlie: 9012\nDavid: 3456\nEve: 7890\nFrank: 1357\nGrace: 2468\nHeidi: 9753\nIvan: 8642\n'

# %%
client.get_number("Alice")
# Out:
# Alice: 1234
# '1234'
