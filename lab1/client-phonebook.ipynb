# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance
# Out:
# 2024-11-03 09:50:38,718 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=58, family=2, type=1, proto=0, laddr=('127.0.0.1', 34900), raddr=('127.0.0.1', 50007)>

# %%
client.get_phonebook()
# Out:
# Phonebook:
# {'Alice': '1234', 'Bob': '5678', 'Charlie': '9012', 'David': '3456', 'Eve': '7890', 'Frank': '1357', 'Grace': '2468', 'Heidi': '9753', 'Ivan': '8642'}
# {'Alice': '1234',
#  'Bob': '5678',
#  'Charlie': '9012',
#  'David': '3456',
#  'Eve': '7890',
#  'Frank': '1357',
#  'Grace': '2468',
#  'Heidi': '9753',
#  'Ivan': '8642'}

# %%
client.get_number("Alice")
# Out:
# {'Alice': '1234'}
